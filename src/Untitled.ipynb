# %%
# %matplotlib inline
import numpy as np

# %%
# %run fit_3pts_01.py
# Out:
# Epoch [1000/50000], Loss: 0.0454
# Epoch [2000/50000], Loss: 0.0425
# Epoch [3000/50000], Loss: 0.0412
# Epoch [4000/50000], Loss: 0.0402
# Epoch [5000/50000], Loss: 0.0394
# Epoch [6000/50000], Loss: 0.0388
# Epoch [7000/50000], Loss: 0.0383
# Epoch [8000/50000], Loss: 0.0379
# Epoch [9000/50000], Loss: 0.0375
# Epoch [10000/50000], Loss: 0.0373
# Epoch [11000/50000], Loss: 0.0370
# Epoch [12000/50000], Loss: 0.0368
# Epoch [13000/50000], Loss: 0.0366
# Epoch [14000/50000], Loss: 0.0364
# Epoch [15000/50000], Loss: 0.0363
# Epoch [16000/50000], Loss: 0.0362
# Epoch [17000/50000], Loss: 0.0361
# Epoch [18000/50000], Loss: 0.0360
# Epoch [19000/50000], Loss: 0.0359
# Epoch [20000/50000], Loss: 0.0358
# Epoch [21000/50000], Loss: 0.0357
# Epoch [22000/50000], Loss: 0.0356
# Epoch [23000/50000], Loss: 0.0356
# Epoch [24000/50000], Loss: 0.0355
# Epoch [25000/50000], Loss: 0.0355
# Epoch [26000/50000], Loss: 0.0354
# Epoch [27000/50000], Loss: 0.0354
# Epoch [28000/50000], Loss: 0.0354
# ...

# %%
ff = lambda x: 1/(1+np.exp(-10*x))

# %%
x = np.linspace(-20,20,1000)
y = ff(x)
plt.plot(x, y)

# %%
y = F.sigmoid(torch.tensor(x))

# %%
plt.plot(x, y.detach().numpy())
