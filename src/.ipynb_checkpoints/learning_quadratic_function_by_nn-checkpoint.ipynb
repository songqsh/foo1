# %% [markdown]
# Our objective is to learn a quadratic function.
# The target function to learn is
# $$f(x) = x^2 + 2$$
# We use the following network for the forward pass, but the result is not good.

# %%
#x = F.dropout(torch.sigmoid(self.fc1(x)), p=0.5)
#x = F.relu(self.fc2(x))
#x = self.fc3(x)

# %%
# %matplotlib inline

# %%
# %run quadfun01.py
# Out:
# Epoch [10000/100000], Loss: 1.9753
# Epoch [20000/100000], Loss: 1.5832
# Epoch [30000/100000], Loss: 1.5116
# Epoch [40000/100000], Loss: 1.1583
# Epoch [50000/100000], Loss: 0.9820
# Epoch [60000/100000], Loss: 0.8281
# Epoch [70000/100000], Loss: 0.8363
# Epoch [80000/100000], Loss: 0.9105
# Epoch [90000/100000], Loss: 0.8940
# Epoch [100000/100000], Loss: 0.7467
