# %% [markdown]
# <a href="https://colab.research.google.com/github/songqsh/foo1/blob/master/src/linalg_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Confirm TensorFlow can see the GPU
#
# - Simply select "GPU" in the Accelerator drop-down in Notebook Settings (either through the Edit menu or the command palette at cmd/ctrl-shift-P).

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#import packages

import tensorflow as tf
import tensorflow.linalg as tfla
import numpy as np
import numpy.linalg as npla

# %%
#run a session
sess = tf.Session()

# %%
#matrix input
# 2-D tensor `a`

a = tf.constant([[1., -1, 0],        
                 [0, 2, 0],
                 [0., 1, 1]])


sess.run(a)
# Out:
# array([[ 1., -1.,  0.],
#        [ 0.,  2.,  0.],
#        [ 0.,  1.,  1.]], dtype=float32)

# %%
# identity matrix

id3 = tf.eye(3)
sess.run(id3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
#transpose

a_trans = tfla.transpose(a)
sess.run(a_trans)
# Out:
# array([[ 1.,  0.,  0.],
#        [-1.,  2.,  1.],
#        [ 0.,  0.,  1.]], dtype=float32)

# %%
#multiplication

prod = a @ a_trans

sess.run(prod)
# Out:
# array([[ 2., -2., -1.],
#        [-2.,  4.,  2.],
#        [-1.,  2.,  2.]], dtype=float32)

# %%
# solver of linear system

soln = tfla.solve(a, id3)
sess.run(soln)
# Out:
# array([[ 1. ,  0.5,  0. ],
#        [ 0. ,  0.5,  0. ],
#        [ 0. , -0.5,  1. ]], dtype=float32)

# %%
#determinant

sess.run(tfla.det(a))
# Out:
# 2.0

# %%
#inverse

a_inv = tfla.inv(a)
sess.run(a_inv)
# Out:
# array([[ 1. ,  0.5,  0. ],
#        [ 0. ,  0.5,  0. ],
#        [ 0. , -0.5,  1. ]], dtype=float32)

# %%
# check inverse

sess.run(a@a_inv)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
#change tensor to numpy array

a_np = sess.run(a)

type(a_np)
# Out:
# numpy.ndarray

# %%
# eigen decomposition
# this is not available in tf, so we have to use np

a_eig_val, a_eig_vec = npla.eig(a_np)
print(a_eig_val)
print(a_eig_vec)
# Out:
# [1. 1. 2.]
# [[ 1.          0.         -0.57735026]
#  [ 0.          0.          0.57735026]
#  [ 0.          1.          0.57735026]]
